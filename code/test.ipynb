# %%
import sys
sys.path.append("D:/sudhendra/learning projects/GraphRAG")

# %%
from src import (
    get_value,
    generate_financial_analysis,
    build_financial_summary
)

# %%
import sys

sys.path.append(
    "D:/sudhendra/learning projects/GraphRAG"
)

from src import generate_financial_analysis

print("Import successful")
# Out:
# Import successful

# %%
from src import get_value, generate_financial_analysis, build_financial_summary

metrics_path = "D:/sudhendra/learning projects/GraphRAG/data/apple_2023_financial_metrics.json"

analysis = generate_financial_analysis(metrics_path, year=2023)

summary = build_financial_summary(analysis)

print(summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 from src import get_value, generate_financial_analysis, build_financial_summary
#       2
#       3 metrics_path = "D:/sudhendra/learning projects/GraphRAG/data/apple_2023_financial_metrics.json"
#       4
# ----> 5 analysis = generate_financial_analysis(metrics_path, year=2023)
#       6
#       7 summary = build_financial_summary(analysis)
#       8
#
# TypeError: generate_financial_analysis() got multiple values for argument 'year'

# %%
import inspect
from src import generate_financial_analysis

print(inspect.signature(generate_financial_analysis))
# Out:
# (year, metrics=None, metrics_path=None)

# %%
analysis = generate_financial_analysis(
    2023,
    metrics_path=metrics_path
)

# %%
summary = build_financial_summary(analysis)

print(summary)
# Out:
# COMPANY FINANCIAL ANALYSIS (2023)
#
# Revenue:
# - Revenue: $383,285 million
# - Revenue growth: -2.80%
#
# Net Income:
# - Net income: $96,995 million
# - Net income growth: -2.81%
#
# Profitability:
# - Gross margin: 44.13%
# - Operating margin: 29.82%
# - Net profit margin: 25.31%
#
# Expense Efficiency:
# - R&D as % of sales: 7.80%
#
# Balance Sheet:
# - Liabilities to assets: 82.37%
# - Cash to assets: 8.50%

# %%
from src import answer_financial_question
